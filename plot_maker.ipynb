# %%
import pickle

# %%
# %run ROC_maker.ipynb

# %%
with open('ghost_DIAG.pkl', 'rb') as input:
    ghost_DIAG = pickle.load(input)
with open('EMPFlow_DIAG.pkl', 'rb') as input:
    EMPFlow_DIAG = pickle.load(input)
with open('cone_DIAG.pkl', 'rb') as input:
    cone_DIAG = pickle.load(input)

# %%
algos=[0,1,1,1,0,1]
x_int=[0.4,0.9]

# %%
roc_lrej(EMPFlow_DIAG,'EMPFlow_DIAG',x_int)
# Out:
# <ipython-input-17-5d2133d5dbc9>:27: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(alg.x_ax[0:len(alg.rej_ip3)],alg.rej_ip3[0:len(alg.rej_ip3)]/den[0:len(alg.rej_ip3)], label='IP3D'+s_den)
# <ipython-input-17-5d2133d5dbc9>:28: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(alg.x_ax[0:len(alg.rej_rnnip)],alg.rej_rnnip[0:len(alg.rej_rnnip)]/den[0:len(alg.rej_rnnip)], label='RNNIP'+s_den)
# <ipython-input-17-5d2133d5dbc9>:29: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(alg.x_ax[0:len(alg.rej_sv1)],alg.rej_sv1[0:len(alg.rej_sv1)]/den[0:len(alg.rej_sv1)], label='SV1'+s_den)
# <ipython-input-17-5d2133d5dbc9>:32: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(alg.x_ax[0:len_min],alg.rej_dl1[0:len_min]/den[0:len_min], label='DL1'+s_den)

# %%
roc_lrej(cone_DIAG,'VR30_cone_diag',x_int)
# Out:
# <ipython-input-17-5d2133d5dbc9>:27: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(alg.x_ax[0:len(alg.rej_ip3)],alg.rej_ip3[0:len(alg.rej_ip3)]/den[0:len(alg.rej_ip3)], label='IP3D'+s_den)
# <ipython-input-17-5d2133d5dbc9>:28: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(alg.x_ax[0:len(alg.rej_rnnip)],alg.rej_rnnip[0:len(alg.rej_rnnip)]/den[0:len(alg.rej_rnnip)], label='RNNIP'+s_den)
# <ipython-input-17-5d2133d5dbc9>:29: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(alg.x_ax[0:len(alg.rej_sv1)],alg.rej_sv1[0:len(alg.rej_sv1)]/den[0:len(alg.rej_sv1)], label='SV1'+s_den)
# <ipython-input-17-5d2133d5dbc9>:32: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(alg.x_ax[0:len_min],alg.rej_dl1[0:len_min]/den[0:len_min], label='DL1'+s_den)

# %%
roc_lrej(ghost_DIAG,'VR30_ghost_diag',x_int)
# Out:
# <ipython-input-17-5d2133d5dbc9>:27: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(alg.x_ax[0:len(alg.rej_ip3)],alg.rej_ip3[0:len(alg.rej_ip3)]/den[0:len(alg.rej_ip3)], label='IP3D'+s_den)
# <ipython-input-17-5d2133d5dbc9>:28: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(alg.x_ax[0:len(alg.rej_rnnip)],alg.rej_rnnip[0:len(alg.rej_rnnip)]/den[0:len(alg.rej_rnnip)], label='RNNIP'+s_den)
# <ipython-input-17-5d2133d5dbc9>:29: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(alg.x_ax[0:len(alg.rej_sv1)],alg.rej_sv1[0:len(alg.rej_sv1)]/den[0:len(alg.rej_sv1)], label='SV1'+s_den)
# <ipython-input-17-5d2133d5dbc9>:32: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(alg.x_ax[0:len_min],alg.rej_dl1[0:len_min]/den[0:len_min], label='DL1'+s_den)

# %%
rec_lconf(EMPFlow_DIAG,'EMPFlow_DIAG',ghost_DIAG,'VR30_ghost_diag',x_int)
# Out:
# <ipython-input-17-db8cdb5781fd>:41: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(x_ax[0:len_min],alg_2.rej_ip3[0:len_min]/den[0:len_min], 'g', label='IP3D - '+mode_2+'/'+s_den)
# <ipython-input-17-db8cdb5781fd>:78: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(x_ax[0:len_min],alg_2.rej_sv1[0:len_min]/den[0:len_min], 'r', label='SV1 - '+mode_2+'/'+s_den)
# <ipython-input-17-db8cdb5781fd>:127: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(x_ax[0:len_min],alg_2.rej_rnnip[0:len_min]/den[0:len_min], 'r', label='RNNIP- '+mode_2+'/'+s_den)
# <ipython-input-17-db8cdb5781fd>:140: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(x_ax[0:len_min],alg_2.rej_dl1[0:len_min]/den[0:len_min], 'g', label='DL1 - '+mode_2+'/'+s_den)

# %%
rec_lconf(EMPFlow_DIAG,'EMPFlow_DIAG',cone_DIAG,'VR30_cone_diag',x_int)
# Out:
# <ipython-input-17-db8cdb5781fd>:41: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(x_ax[0:len_min],alg_2.rej_ip3[0:len_min]/den[0:len_min], 'g', label='IP3D - '+mode_2+'/'+s_den)
# <ipython-input-17-db8cdb5781fd>:78: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(x_ax[0:len_min],alg_2.rej_sv1[0:len_min]/den[0:len_min], 'r', label='SV1 - '+mode_2+'/'+s_den)
# <ipython-input-17-db8cdb5781fd>:127: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(x_ax[0:len_min],alg_2.rej_rnnip[0:len_min]/den[0:len_min], 'r', label='RNNIP- '+mode_2+'/'+s_den)
# <ipython-input-17-db8cdb5781fd>:140: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(x_ax[0:len_min],alg_2.rej_dl1[0:len_min]/den[0:len_min], 'g', label='DL1 - '+mode_2+'/'+s_den)

# %%
rec_lconf(ghost_DIAG,'VR30_ghost_diag',cone_DIAG,'VR30_cone_diag',x_int)
# Out:
# <ipython-input-17-db8cdb5781fd>:41: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(x_ax[0:len_min],alg_2.rej_ip3[0:len_min]/den[0:len_min], 'g', label='IP3D - '+mode_2+'/'+s_den)
# <ipython-input-17-db8cdb5781fd>:78: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(x_ax[0:len_min],alg_2.rej_sv1[0:len_min]/den[0:len_min], 'r', label='SV1 - '+mode_2+'/'+s_den)
# <ipython-input-17-db8cdb5781fd>:127: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(x_ax[0:len_min],alg_2.rej_rnnip[0:len_min]/den[0:len_min], 'r', label='RNNIP- '+mode_2+'/'+s_den)
# <ipython-input-17-db8cdb5781fd>:140: RuntimeWarning: invalid value encountered in true_divide
#   plt.plot(x_ax[0:len_min],alg_2.rej_dl1[0:len_min]/den[0:len_min], 'g', label='DL1 - '+mode_2+'/'+s_den)
